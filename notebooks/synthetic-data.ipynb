# %% [markdown]
# # Experiments Synthetic Data

# %% [markdown]
# ## Imports

# %%
import numpy as np
import random
import sys

from IPython.display import Image

sys.path.append('../')

import lib.experiments as exp

# %% [markdown]
# ## Size x Time Experiments using Synthetic Data

# %%
sizes = range(200, 1001, 200)

num = 10
balance = 1.
sparsity = 0.8
noise = .1
energy = 100
random.seed(3)
np.random.seed(7)
res_t = exp.size_time_experiment(sizes, balance, sparsity, energy, noise, num)

# %%
exp.plot_size_time_experiment(np.array(res_t), sizes,
                              "../figs/size_time_synthetic.png")
Image(filename="../figs/size_time_synthetic.png")

# %% [markdown]
# ## Sparsity x L2 energy Experiments using Synthetic Data

# %%
sparsity = [0.2, 0.4, 0.6, 0.8]
size = 500
num = 10
balance = 1.
noise = .5
energy = 100
random.seed(3)
np.random.seed(7)
res_acc = exp.sparsity_acc_experiment(sparsity, size, balance,
                                      energy, noise, num)

# %%
exp.plot_sparsity_acc_experiment(res_acc, sparsity,
                                 "../figs/sparsity_acc_synthetic.png")
Image(filename="../figs/sparsity_acc_synthetic.png")

# %% [markdown]
# ## L2 energy data x L2 energy Experiments using Synthetic Data

# %%
energy = [10, 100, 1000, 10000]
noise = .5
size = 500
num = 10
sparsity = .5
balance = 1.
random.seed(3)
np.random.seed(7)
res_acc = exp.energy_acc_experiment(energy, size, sparsity,
                                    noise, balance, num)

# %%
exp.plot_energy_acc_experiment(res_acc, energy,
                               "../figs/energy_acc_synthetic.png")

Image(filename="../figs/energy_acc_synthetic.png")

# %% [markdown]
# ## Noise data x L2 energy Experiments using Synthetic Data

# %%
noise = [.2, .4, .6, .8]
size = 500
num = 10
sparsity = 1.
balance = 1.
energy = 100
random.seed(3)
np.random.seed(7)
res_acc = exp.noise_acc_experiment(noise, size, sparsity, energy, balance, num)

# %%
exp.plot_noise_acc_experiment(res_acc, noise, "../figs/noise_acc_synthetic.png")
Image(filename="../figs/noise_acc_synthetic.png")
